# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering the data from the Mayor's 24-hour hotline in Boston

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will do a clustering analysis on the 311 calls that we used in the previous homework. We will focus on choosing a value for k, clustering based on multiple features and detecting outliers.
#
# ---------------------------

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.datasets as sk_data
import sklearn.metrics as metrics
from sklearn.cluster import KMeans
from datetime import datetime
from sklearn.preprocessing import StandardScaler
#import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv')
print boston.info()
print boston.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 33 columns):
# CASE_ENQUIRY_ID                   46698 non-null int64
# OPEN_DT                           46698 non-null object
# TARGET_DT                         41129 non-null object
# CLOSED_DT                         35141 non-null object
# OnTime_Status                     46694 non-null object
# CASE_STATUS                       46698 non-null object
# CLOSURE_REASON                    35175 non-null object
# CASE_TITLE                        46679 non-null object
# SUBJECT                           46698 non-null object
# REASON                            46698 non-null object
# TYPE                              46698 non-null object
# QUEUE                             46698 non-null object
# Department                        46698 non-null object
# SubmittedPhoto                    7245 non-null object
# ClosedPhoto                       1217 non-null object
# Location                          44442 non-null object
# fire_district                     44229 non-null float64
# pwd_district                      44338 non-null object
# city_council_district             44431 non-null float64
# police_district                   44358 non-null object
# neighborhood                      44402 non-null object
# neighborhood_services_district    44431 non-null float64
# ward                              44438 non-null object
# precinct                          44297 non-null float64
# land_usage                        33332 non-null object
# LOCATION_STREET_NAME              44442 non-null object
# LOCATION_ZIPCODE                  35291 non-null float64
# Property_Type                     44442 non-null object
# Property_ID                       44442 non-null float64
# LATITUDE                          46698 non-null float64
# LONGITUDE                         46698 non-null float64
# Source                            46698 non-null object
# Geocoded_Location                 46698 non-null object
# dtypes: float64(8), int64(1), object(24)
# memory usage: 12.1+ MB
# None
#    CASE_ENQUIRY_ID              OPEN_DT            TARGET_DT  \
# 0     101001240734  2015-01-01 00:20:09                  NaN
# 1     101001240735  2015-01-01 00:25:23  2015-01-16 08:30:00
# 2     101001240736  2015-01-01 00:25:36  2015-01-16 08:30:00
# 3     101001240740  2015-01-01 01:45:37                  NaN
# 4     101001240742  2015-01-01 02:24:59                  NaN
#
#              CLOSED_DT OnTime_Status CASE_STATUS  \
# 0  2015-01-02 09:08:42        ONTIME      Closed
# 1  2015-01-02 16:17:43        ONTIME      Closed
# 2                  NaN       OVERDUE        Open
# 3                  NaN        ONTIME        Open
# 4  2015-01-02 09:09:00        ONTIME      Closed
#
#                                       CLOSURE_REASON    CASE_TITLE  \
# 0                             Case Closed Case Noted         Other
# 1  Case Closed Duplicate of Existing Case duplica...       PRINTED
# 2                                                NaN       PRINTED
# 3                                                NaN  Animal Found
# 4                             Case Closed Case Noted          Fire
#
#                    SUBJECT         REASON         ...          precinct  \
# 0  Mayor's 24 Hour Hotline   Notification         ...               503
# 1  Public Works Department  Street Lights         ...               502
# 2  Public Works Department  Street Lights         ...               502
# 3           Animal Control  Animal Issues         ...              2010
# 4  Mayor's 24 Hour Hotline   Notification         ...               708
#
#   land_usage LOCATION_STREET_NAME LOCATION_ZIPCODE Property_Type Property_ID  \
# 0          E         33 Beacon St             2108       Address       11072
# 1          C   145-151 Ipswich St             2215       Address      157262
# 2          C   145-151 Ipswich St             2215       Address      157262
# 3         R4   4833 Washington St             2132       Address      331760
# 4         R2       10 Washburn St             2125       Address      143386
#
#    LATITUDE LONGITUDE                Source    Geocoded_Location
# 0   42.3574  -71.0648      Constituent Call  (42.3574, -71.0648)
# 1   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 2   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 3   42.2711  -71.1464      Constituent Call  (42.2711, -71.1464)
# 4   42.3254  -71.0574      Constituent Call  (42.3254, -71.0574)
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Step 1. Simple clustering

# %% [markdown]
# The first thing that we will try is to cluster the geolocation data of the calls. The geolocation of a record consists of a pair `(latitude, longitude)`, which represents the position of the record on the map. Since the dataset that we have spans only a small geographic location, i.e. Boston, we will use the Euclidean distance when measuring how close two points are. Techinically, we should pick a [projection](https://github.com/mbostock/d3/wiki/Geo-Projections) in order to transform the data into 2d, and measure  the Euclidean distance in the projected space.

# %% [markdown]
# Since we are dealing with numeric data, we might consider centering and normalizing them. In order to do that, check the [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler) from `scikit-learn`.

# %% [markdown]
# For exampe, the result of a clustering with 10 clusters is the following:
#
#
# ![A clustering of the locations of the calls for k=10](clusters10.png)

# %% [markdown]
# Filter the dataset to get the latitude and longitude, transform it as required and run the k-means clustering algorithm. Argue about the number of clusters you used. **(pts 50)**

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv', parse_dates=[1,2,3])
boston.neighborhood.value_counts()
s = boston[["LATITUDE", 'LONGITUDE']]
scaler = StandardScaler()
boston['neighborhood'].value_counts()
s_scaled = pd.DataFrame(scaler.fit(s).transform(s))#maybe try calling scaler on the columns individually
s_scaled.columns = ['lat','lon']
kmeans = KMeans(init='k-means++', n_clusters=22, n_init=10) #23 is the number of unique
#neighborhoods in the data set, but there is only one entry for Chesnut hill, so i'm only going to 
#do 22 clusters
#you can see below that the "elbow" in the data actually appears around 3 clusters, so that's what I'll be going with from now
#on despite my initial hunch that 22 might be good. It is, of course, a better fit, but that's because fit will almost always
#improve with a larger number of clusters.
kmeans.fit_predict(s_scaled)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_
s_scaled['label'] = labels
print s_scaled.head()
forfun = pd.DataFrame(centroids)
forfun.columns = ['0','1']
plt.scatter(forfun['0'],forfun['1'])
# Out:
#         lat       lon  label
# 0  0.957006  0.561375      5
# 1  0.668763 -0.273099     20
# 2  0.668763 -0.273099     20
# 3 -1.530531 -1.739066      7
# 4  0.034629  0.769993      8

# %%
error = np.zeros(22)
error[0] = 0;
for k in range(1,22):
    kmeans = KMeans(init='k-means++', n_clusters=k, n_init=10)
    kmeans.fit_predict(s_scaled)
    error[k] = kmeans.inertia_

plt.plot(range(1,len(error)),error[1:])
plt.xlabel('Number of clusters')
plt.ylabel('Error')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = []
for i in range(7):
    #cmap.extend(sns.hls_palette(n_colors=8, h=0.7, l=0.4, s=0.8))
    cmap.extend(['b','g','r','y','k','c','m'])
# for each label, isolate the points of that label and plot them with the same color
labels = s_scaled['label']
for i, label in enumerate(set(labels)):
    point_indices = np.where(labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(s_scaled.iloc[point_indices,1], s_scaled.iloc[point_indices, 0], s=25, alpha=0.2, c=cmap[i], marker='+') #right
    #i'm plotting all the points every time! BOO

# %% [markdown]
# -----

# %% [markdown]
# ## Step 2. Using multiple features

# %% [markdown]
# The next step in our analysis is to use more features than just the geolocation of a record (whose clustering only gives us information about the neighborhoods, which should not be a huge revelation!) Filter the dataset to get more features, transform them as required and compute another clustering. You should argue about the quality of your clustering and use domain knowledge (i.e. the fact that you are locals) to explore the clusters you produced and present them to the reader. **(pts 30)**

# %%
t = boston[["LATITUDE", 'LONGITUDE',"fire_district","city_council_district","precinct"]] #these are the other numerical data"
t = t.fillna(0) #I'm not 100% sure about this step, it seems like this would introduce some serious data analysis problems since
#a value of '0' actually has meaning here...in fact, it means "average" when we scale.
t_scaled = pd.DataFrame(scaler.fit(t[["LATITUDE", 'LONGITUDE',"fire_district","city_council_district","precinct"]]).transform(t[["LATITUDE", 'LONGITUDE',"fire_district","city_council_district","precinct"]]))
t_scaled.columns = ['lat','lon', 'fire', 'council', 'precinct']
kmeans = KMeans(init='k-means++', n_clusters=22, n_init=10) #23 is the number of unique
#neighborhoods in the data set, but there is only one entry for Chesnut hill, so i'm only going to 
#do 22 clusters
kmeans.fit_predict(t_scaled)
centroids_t = kmeans.cluster_centers_
labels_t = kmeans.labels_
error_t = kmeans.inertia_
t_scaled['cluster'] = labels
forfun_t = pd.DataFrame(centroids_t)
forfun_t.columns = ['0','1','2','3','4']
g = sns.PairGrid(forfun_t)
g.map(plt.scatter)


'''
the strength of the clustering should be improved by the addition of the data columns we included. this is because the
fire districts, city council districts, and police precincts are all geographical entities. This means that the clustering
algorithm has more power to compute clusters from the data which actually correspond to the geographical location. That being
said, the actual GPS data are pretty powerful clustering tools, since they do cluster the data naturally. I'm not sure if this
section was meant to make us use some other sort of data (strings, fex), but I've only ever seen Kmeans++ applied to numerical
data, so I wasn't sure if that was possible?
'''
# Out:
# "\nthe strength of the clustering should be improved by the addition of the data columns we included. this is because the\nfire districts, city council districts, and police precincts are all geographical entities. This means that the clustering\nalgorithm has more power to compute clusters from the data which actually correspond to the geographical location. That being\nsaid, the actual GPS data are pretty powerful clustering tools, since they do cluster the data naturally. I'm not sure if this\nsection was meant to make us use some other sort of data (strings, fex), but I've only ever seen Kmeans++ applied to numerical\ndata, so I wasn't sure if that was possible?\n"

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=4)
cmap.extend(sns.hls_palette(n_colors=6, h=0.7, l=0.4, s=0.8))
# for each label, isolate the points of that label and plot them with the same color
for i, label_t in enumerate(set(labels)):
    point_indices = np.where(labels == label_t)[0]
    point_indices = point_indices.tolist()
    plt.scatter(t_scaled['lon'], t_scaled['lat'], s=25, alpha=0.2, c=cmap[i], marker='+')

# %% [markdown]
# -----

# %% [markdown]
# ## Step 3. Detecting outliers

# %% [markdown]
# Now that we have a clustering of the records in the dataset, we can detect the outlying ones. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(pts 20)**

# %%
#in this cell I was just messing around with different ways of slicing for values etc.
df = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])
df['d'].iloc[3] = 2222
df['e'] = np.random.randn(len(df))
euclidean_dist = metrics.euclidean_distances(df.iloc[[1]], df.iloc[[2]])
print df
print df.iloc[0:1,3:4] #column then row
#print euclidean_dist
#print df['b'].iloc[[3]]
print df[np.abs(df.d-df.d.mean())>(2*df.d.std())] #calculates the absolute value of each value of df.d - df.d.mean()
#only if it's larger than 2 standard deviations from the mean
# Out:
#           a         b         c            d         e
# 0 -1.007037 -0.366353  0.630515     0.424424 -0.381745
# 1  0.040014  0.475441 -0.125104     1.191253 -1.119045
# 2  1.196087 -0.335566 -0.139194    -1.678711  1.972098
# 3 -0.491696  0.363332 -0.412063  2222.000000 -1.695553
# 4 -1.005219 -0.599850  1.346072     0.006685 -0.753761
# 5 -0.058811 -0.940312  0.261132    -1.158375 -1.829116
# 6  0.101226 -1.838632  0.277094     0.220957  2.189836
# 7 -1.566144  0.676998  0.634113    -1.135342 -0.721956
# 8 -0.342439  0.164107 -0.418483    -0.019740 -0.817871
# 9  0.231734  0.828067 -0.006708    -1.886894 -0.817386
#           d
# 0  0.424424
#           a         b         c     d         e
# 3 -0.491696  0.363332 -0.412063  2222 -1.695553

# %% [markdown]
# calculate euclidian distances for each from the center of its assigned cluster
# make that a new column
# pass max on a groupby of that column by cluster

# %%
#I think this works!!
def get_outliers(df_name, cluster_column, cluster_centers):
    #df_name = raw_input("what is the variable name of your Data Frame?   ")
    #cluster_column = raw_input("what is the header of your cluster column in the Data Frame?   ")
    #cluster_centers = raw_input("what is the variable name of your cluster centroids?   ")
    df_name['distances'] = np.random.randn(len(df_name))
    
    for index, row in df_name.iterrows():
        center = cluster_centers[df_name[cluster_column].iloc[[index]]]
        euclidean = metrics.euclidean_distances(center,df_name.iloc[index,0:2])
        df_name.iloc[i,-1] = float(euclidean)
        #it was taking a REALLY long time to run, so I left the break in there for now
    return df_name[np.abs(df_name['distances']-df_name['distances'].mean())>(3*df_name['distances'].std())] #calculates the absolute value of each value of df.d - df.d.mean()
    #only if it's larger than 2 standard deviations from the mean
    
get_outliers(s_scaled,"label",centroids)

#if you have time try this: 
#http://scikit-learn.org/stable/auto_examples/covariance/plot_outlier_detection.html
# Out:
#             lat       lon  label  distances
# 18    -0.023020 -0.250545      1  -2.225097
# 21     0.092277  0.152595      1   3.177342
# 26     0.980066  0.626216      2  -2.139221
# 68     1.591141  0.440151      2  -2.618719
# 73     0.351696  0.014456      2  -2.261776
# 75     0.654351  0.313288      2  -2.574975
# 180    0.147043 -0.405600      1  -2.294887
# 207    0.553466  0.468342      2   2.205759
# 221   -1.985955 -1.121668      0   2.714581
# 240   -0.804159  0.710791      1   2.866469
# 245   -0.438090 -0.958156      0  -2.975986
# 248    1.565199  0.617758      2   2.052811
# 252    0.631292 -1.722151      0  -2.044684
# 264    0.374755  1.308454      2  -2.123700
# 292   -1.031871 -2.223962      0  -2.182857
# 317    0.513112 -0.050385      2  -2.299119
# 347    0.158573  1.339465      2  -2.128984
# 395    0.216222  1.051910      2   2.885520
# 431    0.928182  0.434512      2   2.614184
# 432    0.221987 -0.797464      0   2.058535
# 435   -1.412351 -1.307733      0   2.321618
# 453   -0.541857 -1.180870      0  -2.554262
# 492   -1.199052 -0.853847      0  -2.496863
# 548    1.530610  1.548083      2   2.190111
# 586   -1.467118 -0.653686      0  -2.018653
# 588    0.683175 -0.025012      2   2.110339
# 643   -1.155815 -0.047565      1   2.246531
# 661   -1.305702  0.848930      1   2.107894
# 681   -1.484412 -0.163151      1   3.650800
# 682    1.349017  1.407125      2   2.743171
# ...         ...       ...    ...        ...
# 46018  0.455463  0.231532      2  -2.284634
# 46047 -0.861807  0.676961      1   2.053459
# 46068  0.573643  0.144138      2   2.069099
# 46081 -0.037432  0.736163      1  -2.075309
# 46088  1.014655  0.733344      2   2.298204
# 46105  0.694705  0.234351      2  -2.213245
# 46139  1.014655  0.733344      2  -2.603951
# 46149  0.507347 -0.332301      2  -3.065560
# 46236  0.233516  1.246432      2  -2.217396
# 46251  0.550584  0.349937      2  -2.625389
# 46365  0.256576  1.393029      2   2.700183
# 46382  1.591141  0.507811      2  -2.812083
# 46409 -0.567799 -0.710070      0   2.283738
# 46449 -0.080669 -0.676240      0   2.407091
# 46457 -0.187319  0.310469      1   2.363652
# 46462  1.014655  0.733344      2   2.400535
# 46488  1.014655  0.733344      2  -2.232855
# 46500 -1.637181 -0.642410      0   2.463402
# 46546  0.933947 -1.553000      0   2.153719
# 46562 -1.452705 -2.336729      0   2.316332
# 46574  0.210457  0.014456      1   2.111683
# 46604 -0.406383 -0.160332      1   2.377098
# 46624 -0.948280 -2.305718      0   2.636119
# 46645 -0.619683  0.609301      1   2.316788
# 46647 -1.109696  0.575471      1   2.559789
# 46664  1.014655  0.733344      2  -2.465346
# 46671  1.276956  1.291539      2   2.983417
# 46679  1.418195  1.409944      2   2.317172
# 46688  0.518877  0.130042      2  -2.019084
# 46691 -1.435411  0.211798      1  -2.428768
#
# [2083 rows x 4 columns]

# %%
# Code for setting the style of the notebook
#from IPython.core.display import HTML
#def css_styling():
#    styles = open("../../theme/custom.css", "r").read()
#    return HTML(styles)
#css_styling()
