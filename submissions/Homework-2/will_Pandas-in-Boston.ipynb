# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Analyze the data from the Mayor's 24-hour hotline in Boston using Pandas

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will practice some basic skills on working with data. We will see how to read, access, clean, filter and plot a dataset.
#
# ---------------------------

# %% [markdown]
# ## Step 1. Downaloading the data

# %% [markdown]
# The data that we will be using are freely available online, by the [City of Boston](https://data.cityofboston.gov/). A brief description of the 311 service can be found [here](http://www.cityofboston.gov/mayor/24/). You can download the whole dataset, which extends from 2011 until now (updated every day) from [here](https://data.cityofboston.gov/City-Services/Mayor-s-24-Hour-Hotline-Service-Requests/awu8-dc52?). However, it contains over 555,000 records and, as a result, it's more than 245 MB in size. In the homework repository, you can find a small part of it that covers the months of January-February 2015, under the filename `cases_2015.csv`.

# %% [markdown]
# During these two months, Boston experienced one of the highest levels of snowfalls. We will take this opportunity and see how this situation affected the 311 center. We will also be using data from [NOAA National Climatic Data Center](http://www.ncdc.noaa.gov/cdo-web/) regarding the levels of snowfall for the dates that we are interested in. This dataset is also available in our repository for your convenience under the file `snow.csv`. You can read its documentation [here](http://www.ncdc.noaa.gov/cdo-web/datasets).

# %% [markdown]
# -----------------

# %% [markdown]
# ## Step 2. Reading the data

# %% [markdown]
# The first thing we want to do is load the data as Pandas *DataFrames*.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt

# %%
boston = pd.read_csv('cases_2015.csv')

# %% [markdown]
# We need to take a brief look at the data, so that we get an intuition about what we are dealing with. Your first task is to do just that: print some part of the dataset **(5 pts)**

# %%
boston.head()
# Out:
#    CASE_ENQUIRY_ID              OPEN_DT            TARGET_DT  \
# 0     101001240734  2015-01-01 00:20:09                  NaN
# 1     101001240735  2015-01-01 00:25:23  2015-01-16 08:30:00
# 2     101001240736  2015-01-01 00:25:36  2015-01-16 08:30:00
# 3     101001240740  2015-01-01 01:45:37                  NaN
# 4     101001240742  2015-01-01 02:24:59                  NaN
#
#              CLOSED_DT OnTime_Status CASE_STATUS  \
# 0  2015-01-02 09:08:42        ONTIME      Closed
# 1  2015-01-02 16:17:43        ONTIME      Closed
# 2                  NaN       OVERDUE        Open
# 3                  NaN        ONTIME        Open
# 4  2015-01-02 09:09:00        ONTIME      Closed
#
#                                       CLOSURE_REASON    CASE_TITLE  \
# 0                             Case Closed Case Noted         Other
# 1  Case Closed Duplicate of Existing Case duplica...       PRINTED
# 2                                                NaN       PRINTED
# 3                                                NaN  Animal Found
# 4                             Case Closed Case Noted          Fire
#
#                    SUBJECT         REASON         ...          precinct  \
# 0  Mayor's 24 Hour Hotline   Notification         ...               503
# 1  Public Works Department  Street Lights         ...               502
# 2  Public Works Department  Street Lights         ...               502
# 3           Animal Control  Animal Issues         ...              2010
# 4  Mayor's 24 Hour Hotline   Notification         ...               708
#
#   land_usage LOCATION_STREET_NAME LOCATION_ZIPCODE Property_Type Property_ID  \
# 0          E         33 Beacon St             2108       Address       11072
# 1          C   145-151 Ipswich St             2215       Address      157262
# 2          C   145-151 Ipswich St             2215       Address      157262
# 3         R4   4833 Washington St             2132       Address      331760
# 4         R2       10 Washburn St             2125       Address      143386
#
#    LATITUDE LONGITUDE                Source    Geocoded_Location
# 0   42.3574  -71.0648      Constituent Call  (42.3574, -71.0648)
# 1   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 2   42.3474  -71.0944  Citizens Connect App  (42.3474, -71.0944)
# 3   42.2711  -71.1464      Constituent Call  (42.2711, -71.1464)
# 4   42.3254  -71.0574      Constituent Call  (42.3254, -71.0574)
#
# [5 rows x 33 columns]

# %% [markdown]
# Another useful thing is to get a short summary of the columns and their data types. Make a call to the required function for this **(5 pts)**

# %%
boston.columns
#boston.OPEN_DT.head()
# Out:
# Index([u'CASE_ENQUIRY_ID', u'OPEN_DT', u'TARGET_DT', u'CLOSED_DT', u'OnTime_Status', u'CASE_STATUS', u'CLOSURE_REASON', u'CASE_TITLE', u'SUBJECT', u'REASON', u'TYPE', u'QUEUE', u'Department', u'SubmittedPhoto', u'ClosedPhoto', u'Location', u'fire_district', u'pwd_district', u'city_council_district', u'police_district', u'neighborhood', u'neighborhood_services_district', u'ward', u'precinct', u'land_usage', u'LOCATION_STREET_NAME', u'LOCATION_ZIPCODE', u'Property_Type', u'Property_ID', u'LATITUDE', u'LONGITUDE', u'Source', u'Geocoded_Location'], dtype='object')

# %% [markdown]
# As you can see, the `OPEN_DT`, `TARGET_DT`, and `CLOSED_DT` columns, all of which should be dates, have been misclassified as `object` instead of datetime. Re-write the code that reads from a csv, in order to parse the above columns as datetimes. **(5 pts)**

# %%
boston= pd.read_csv('cases_2015.csv',parse_dates=['OPEN_DT','TARGET_DT','CLOSED_DT'])
#boston.open_dt.apply(lambda d: datetime.strptime(d, "%Y-%m-%d %H:%M:%S"))
#boston.target_dt
#if boston.target_dt != 'NaN':
    #boston.target_dt.apply(lambda d: datetime.strptime(d, "%Y-%m-%d %H:%M:%S"))
#boston.closed_dt.apply(lambda d: datetime.strptime(d, "%Y-%m-%d %H:%M:%S"))
boston.OPEN_DT.head()
# Out:
# 0   2015-01-01 00:20:09
# 1   2015-01-01 00:25:23
# 2   2015-01-01 00:25:36
# 3   2015-01-01 01:45:37
# 4   2015-01-01 02:24:59
# Name: OPEN_DT, dtype: datetime64[ns]

# %% [markdown]
# Make sure that the column data types are exactly as expected:

# %%
new_columns = [ x.lower().replace(' ','_') for x in boston.columns]
boston.columns = new_columns
boston.open_dt.tail(25930)
#boston.target_dt.head()
#boston.closed_dt.head()
# Out:
# 20768   2015-01-31 22:45:15
# 20769   2015-01-31 22:48:02
# 20770   2015-01-31 22:51:33
# 20771   2015-01-31 23:07:04
# 20772   2015-01-31 23:08:27
# 20773   2015-01-31 23:21:18
# 20774   2015-01-31 23:22:51
# 20775   2015-01-31 23:34:47
# 20776   2015-01-31 23:48:19
# 20777   2015-02-01 00:11:47
# 20778   2015-02-01 00:12:23
# 20779   2015-02-01 00:14:44
# 20780   2015-02-01 00:19:43
# 20781   2015-02-01 00:20:03
# 20782   2015-02-01 00:20:42
# ...
# 46683   2015-02-14 22:32:35
# 46684   2015-02-14 22:40:31
# 46685   2015-02-14 22:44:37
# 46686   2015-02-14 22:45:06
# 46687   2015-02-14 22:55:01
# 46688   2015-02-14 22:57:46
# 46689   2015-02-14 23:20:20
# 46690   2015-02-14 23:26:57
# 46691   2015-02-14 23:28:30
# 46692   2015-02-14 23:29:22
# 46693   2015-02-14 23:37:51
# 46694   2015-02-14 23:41:25
# 46695   2015-02-14 23:46:19
# 46696   2015-02-14 23:53:09
# 46697   2015-02-15 00:00:17
# Name: open_dt, Length: 25930, dtype: datetime64[ns]

# %% [markdown]
# ## Step 3. Filtering and plotting the data

# %% [markdown]
# Now that we read the data and took a quick look, we can start playing around with it. As you have already noticed, there is very little documentation on the dataset itself. In such occasions, we need to look at the dataset very extensively, to get a good feel of its structure. This part, together with what we will do next, is a significant part of the *data cleaning* process.

# %% [markdown]
# To practice our filtering skills, let's try to isolate the cases that were opened in February **(5 pts)**

# %%
boston.index = boston.open_dt
boston.drop(['open_dt'], axis=1)
# Write code that filters the dataframe and keeps only the cases that were opened in February
#In [1712]: start = datetime(2011, 1, 1)

#february = boston.truncate[before='2015-02-01', after='2015-02-16']
february = boston['2015-02']
february.head()
february.tail()
# Out:
#                      case_enquiry_id             open_dt           target_dt  \
# open_dt
# 2015-02-14 23:37:51     101001295400 2015-02-14 23:37:51 2015-02-19 08:30:00
# 2015-02-14 23:41:25     101001295401 2015-02-14 23:41:25                 NaT
# 2015-02-14 23:46:19     101001295402 2015-02-14 23:46:19 2015-02-24 08:30:00
# 2015-02-14 23:53:09     101001295406 2015-02-14 23:53:09 2015-03-03 08:30:00
# 2015-02-15 00:00:17     101001295407 2015-02-15 00:00:17                 NaT
#
#                     closed_dt ontime_status case_status closure_reason  \
# open_dt
# 2015-02-14 23:37:51       NaT        ONTIME        Open            NaN
# 2015-02-14 23:41:25       NaT        ONTIME        Open            NaN
# 2015-02-14 23:46:19       NaT        ONTIME        Open            NaN
# 2015-02-14 23:53:09       NaT        ONTIME        Open            NaN
# 2015-02-15 00:00:17       NaT        ONTIME        Open            NaN
#
#                                                          case_title  \
# open_dt
# 2015-02-14 23:37:51                        Request for Snow Plowing
# 2015-02-14 23:41:25  Request for Snow Plowing (Emergency Responder)
# 2015-02-14 23:46:19                                    Snow Removal
# 2015-02-14 23:53:09                          PublicWorks: Complaint
# 2015-02-15 00:00:17                            Misc. Snow Complaint
#
#                                      subject  \
# open_dt
# 2015-02-14 23:37:51  Public Works Department
# 2015-02-14 23:41:25  Public Works Department
# 2015-02-14 23:46:19    Inspectional Services
# 2015-02-14 23:53:09  Mayor's 24 Hour Hotline
# 2015-02-15 00:00:17  Public Works Department
#
#                                                 reason         ...           \
# open_dt                                                        ...
# 2015-02-14 23:37:51                    Street Cleaning         ...
# 2015-02-14 23:41:25                    Street Cleaning         ...
# 2015-02-14 23:46:19                   Code Enforcement         ...
# 2015-02-14 23:53:09        Employee & General Comments         ...
# 2015-02-15 00:00:17  Administrative & General Requests         ...
#
#                     precinct land_usage  location_street_name  \
# open_dt
# 2015-02-14 23:37:51     1901         R2  110-112 Paul Gore St
# 2015-02-14 23:41:25     1807          C     456 Hyde Park Ave
# 2015-02-14 23:46:19     1803         R3    1450 Blue Hill Ave
# 2015-02-14 23:53:09      NaN        NaN                   NaN
# 2015-02-15 00:00:17     1803         R3    1438 Blue Hill Ave
#
#                     location_zipcode property_type property_id  latitude  \
# open_dt
# 2015-02-14 23:37:51             2130       Address      108519   42.3187
# 2015-02-14 23:41:25             2131       Address      157930   42.2850
# 2015-02-14 23:46:19             2126       Address      189748   42.2745
# 2015-02-14 23:53:09              NaN           NaN         NaN   42.3594
# 2015-02-15 00:00:17             2126       Address       16276   42.2749
#
#                     longitude                source    geocoded_location
# open_dt
# 2015-02-14 23:37:51  -71.1061  Citizens Connect App  (42.3187, -71.1061)
# 2015-02-14 23:41:25  -71.1187      Constituent Call   (42.285, -71.1187)
# 2015-02-14 23:46:19  -71.0932          Self Service  (42.2745, -71.0932)
# 2015-02-14 23:53:09  -71.0587      Constituent Call  (42.3594, -71.0587)
# 2015-02-15 00:00:17  -71.0932      Constituent Call  (42.2749, -71.0932)
#
# [5 rows x 33 columns]

# %% [markdown]
# Can you do the same thing, but only for the cases that are still remaining open? **(5 pts)**

# %%
open_february = february[february.case_status == 'Open']
open_february.head()
# Out:
#                      case_enquiry_id             open_dt           target_dt  \
# open_dt
# 2015-02-01 00:20:42     101001266305 2015-02-01 00:20:42                 NaT
# 2015-02-01 00:21:41     101001266306 2015-02-01 00:21:41 2015-02-04 08:30:00
# 2015-02-01 00:36:38     101001266307 2015-02-01 00:36:38 2015-02-09 08:30:00
# 2015-02-01 00:45:12     101001266310 2015-02-01 00:45:12 2015-02-17 08:30:00
# 2015-02-01 01:05:29     101001266313 2015-02-01 01:05:29 2015-02-04 08:30:00
#
#                     closed_dt ontime_status case_status closure_reason  \
# open_dt
# 2015-02-01 00:20:42       NaT        ONTIME        Open            NaN
# 2015-02-01 00:21:41       NaT       OVERDUE        Open            NaN
# 2015-02-01 00:36:38       NaT       OVERDUE        Open            NaN
# 2015-02-01 00:45:12       NaT        ONTIME        Open            NaN
# 2015-02-01 01:05:29       NaT       OVERDUE        Open            NaN
#
#                                        case_title                  subject  \
# open_dt
# 2015-02-01 00:20:42                          Fire  Mayor's 24 Hour Hotline
# 2015-02-01 00:21:41    Request for Pothole Repair  Public Works Department
# 2015-02-01 00:36:38                    Electrical    Inspectional Services
# 2015-02-01 00:45:12          Street Light Outages  Public Works Department
# 2015-02-01 01:05:29  Requests for Street Cleaning  Public Works Department
#
#                                   reason         ...          precinct  \
# open_dt                                          ...
# 2015-02-01 00:20:42         Notification         ...               601
# 2015-02-01 00:21:41  Highway Maintenance         ...               407
# 2015-02-01 00:36:38             Building         ...              1308
# 2015-02-01 00:45:12        Street Lights         ...              2008
# 2015-02-01 01:05:29      Street Cleaning         ...              1705
#
#                     land_usage                      location_street_name  \
# open_dt
# 2015-02-01 00:20:42          C                       347-351 Congress St
# 2015-02-01 00:21:41          C                                 36 Fenway
# 2015-02-01 00:36:38         R3                              66 Romsey St
# 2015-02-01 00:45:12        NaN  INTERSECTION Aldrich St & W Roxbury Pkwy
# 2015-02-01 01:05:29          E                          133 Southern Ave
#
#                     location_zipcode property_type property_id  latitude  \
# open_dt
# 2015-02-01 00:20:42             2210       Address       42105   42.3503
# 2015-02-01 00:21:41             2215       Address       57448   42.3454
# 2015-02-01 00:36:38             2125       Address      118181   42.3159
# 2015-02-01 00:45:12              NaN  Intersection         250   42.2815
# 2015-02-01 01:05:29             2124       Address      129159   42.2897
#
#                     longitude                source    geocoded_location
# open_dt
# 2015-02-01 00:20:42  -71.0489      Constituent Call  (42.3503, -71.0489)
# 2015-02-01 00:21:41  -71.0902  Citizens Connect App  (42.3454, -71.0902)
# 2015-02-01 00:36:38  -71.0536      Constituent Call  (42.3159, -71.0536)
# 2015-02-01 00:45:12  -71.1447  Citizens Connect App  (42.2815, -71.1447)
# 2015-02-01 01:05:29  -71.0780  Citizens Connect App   (42.2897, -71.078)
#
# [5 rows x 33 columns]

# %% [markdown]
# Great! Now, let's check all the different values of the column `CASE_TITLE` together with their counts **(5 pts)**

# %%
# Write code that prints the different values of the column 'CASE_TITLE'
# and the count for the occurencies of each value in the boston dataframe
case_categories = {}
for idx, row in boston.iterrows():
    if row.case_title not in case_categories:
        case_categories[row.case_title] = 1
    else:
        case_categories[row.case_title]+=1
        
case_categories= pd.DataFrame(case_categories.items(), columns=['category', 'occurences'])
case_categories.head()
# Out:
#                   category  occurences
# 0                      NaN          19
# 1  Graffiti: Ward 13  1310           1
# 2        Holmes Elementary           1
# 3                     Lead           7
# 4     Misc. Snow Complaint         768

# %% [markdown]
# During this process, you may encounter many strange things, that look like outliers. For example, you may notice that there are many values for `CASE_TITLE` which only occur once. One such example is the category
# ```
# "missing pb cover/printed for jim"
# ```
# I really wonder what this means! Try retrieving and printing the whole row **(5 pts)**

# %%
# Print the row tht has CASE_TITLE "missing pb cover/printed for jim"
boston.loc[boston['case_title']=='missing pb cover/printed for jim']
# Out:
#                      case_enquiry_id             open_dt           target_dt  \
# open_dt
# 2015-01-02 23:18:08     101001241573 2015-01-02 23:18:08 2015-02-16 23:18:08
#
#                     closed_dt ontime_status case_status closure_reason  \
# open_dt
# 2015-01-02 23:18:08       NaT        ONTIME        Open            NaN
#
#                                            case_title  \
# open_dt
# 2015-01-02 23:18:08  missing pb cover/printed for jim
#
#                                      subject         reason  \
# open_dt
# 2015-01-02 23:18:08  Public Works Department  Street Lights
#
#                             ...         precinct land_usage  \
# open_dt                     ...
# 2015-01-02 23:18:08         ...              807        NaN
#
#                                                 location_street_name  \
# open_dt
# 2015-01-02 23:18:08  INTERSECTION Blue Hill Ave & Mount Pleasant Ave
#
#                     location_zipcode property_type property_id  latitude  \
# open_dt
# 2015-01-02 23:18:08              NaN  Intersection        1606   42.3253
#
#                     longitude            source   geocoded_location
# open_dt
# 2015-01-02 23:18:08   -71.075  Constituent Call  (42.3253, -71.075)
#
# [1 rows x 33 columns]

# %% [markdown]
# There's another category which seems interesting, `Heat - Excessive Insufficient`. Write code that prints the first 10 rows of the dataset that have `CASE_TITLE` which starts with "Heat" and see if you can understand what this stands for **(15 pts)**

# %%
boston[boston['case_title'].str.startswith("Heat",na=False)].head(10)
# Out:
#                      case_enquiry_id             open_dt           target_dt  \
# open_dt
# 2015-01-01 07:27:13     101001240754 2015-01-01 07:27:13 2015-01-31 07:27:13
# 2015-01-01 08:53:51     101001240762 2015-01-01 08:53:51 2015-01-31 08:53:51
# 2015-01-01 10:59:01     101001240786 2015-01-01 10:59:01 2015-01-31 10:59:01
# 2015-01-01 12:37:13     101001240809 2015-01-01 12:37:13 2015-01-31 12:37:13
# 2015-01-01 14:24:55     101001240837 2015-01-01 14:24:55 2015-01-31 14:24:55
# 2015-01-01 14:25:24     101001240838 2015-01-01 14:25:24 2015-01-31 14:25:23
# 2015-01-01 14:44:54     101001240842 2015-01-01 14:44:54 2015-01-31 14:44:54
# 2015-01-01 17:13:28     101001240863 2015-01-01 17:13:28 2015-01-31 17:13:28
# 2015-01-01 19:25:55     101001240882 2015-01-01 19:25:55 2015-01-31 19:25:55
# 2015-01-01 22:11:51     101001240896 2015-01-01 22:11:51 2015-01-31 22:11:50
#
#                               closed_dt ontime_status case_status  \
# open_dt
# 2015-01-01 07:27:13                 NaT       OVERDUE        Open
# 2015-01-01 08:53:51                 NaT       OVERDUE        Open
# 2015-01-01 10:59:01 2015-01-07 08:49:25        ONTIME      Closed
# 2015-01-01 12:37:13                 NaT       OVERDUE        Open
# 2015-01-01 14:24:55 2015-01-01 14:32:32        ONTIME      Closed
# 2015-01-01 14:25:24                 NaT       OVERDUE        Open
# 2015-01-01 14:44:54                 NaT       OVERDUE        Open
# 2015-01-01 17:13:28                 NaT       OVERDUE        Open
# 2015-01-01 19:25:55                 NaT       OVERDUE        Open
# 2015-01-01 22:11:51                 NaT       OVERDUE        Open
#
#                                                         closure_reason  \
# open_dt
# 2015-01-01 07:27:13                                                NaN
# 2015-01-01 08:53:51                                                NaN
# 2015-01-01 10:59:01                                      Case Closed :
# 2015-01-01 12:37:13                                                NaN
# 2015-01-01 14:24:55  Case Closed Case Invalid landlord called while...
# 2015-01-01 14:25:24                                                NaN
# 2015-01-01 14:44:54                                                NaN
# 2015-01-01 17:13:28                                                NaN
# 2015-01-01 19:25:55                                                NaN
# 2015-01-01 22:11:51                                                NaN
#
#                                          case_title                subject  \
# open_dt
# 2015-01-01 07:27:13  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 08:53:51  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 10:59:01  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 12:37:13  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 14:24:55  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 14:25:24  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 14:44:54  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 17:13:28  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 19:25:55  Heat - Excessive  Insufficient  Inspectional Services
# 2015-01-01 22:11:51  Heat - Excessive  Insufficient  Inspectional Services
#
#                       reason         ...          precinct land_usage  \
# open_dt                              ...
# 2015-01-01 07:27:13  Housing         ...               802        NaN
# 2015-01-01 08:53:51  Housing         ...               903         EA
# 2015-01-01 10:59:01  Housing         ...               401         RC
# 2015-01-01 12:37:13  Housing         ...              1403          A
# 2015-01-01 14:24:55  Housing         ...              2003         R2
# 2015-01-01 14:25:24  Housing         ...               401         RC
# 2015-01-01 14:44:54  Housing         ...              2104          A
# 2015-01-01 17:13:28  Housing         ...               802         CM
# 2015-01-01 19:25:55  Housing         ...              1808          A
# 2015-01-01 22:11:51  Housing         ...              1407          A
#
#                         location_street_name location_zipcode property_type  \
# open_dt
# 2015-01-01 07:27:13       1744 Washington St             2118       Address
# 2015-01-01 08:53:51             77 Camden St             2118       Address
# 2015-01-01 10:59:01         282 Columbus Ave             2116       Address
# 2015-01-01 12:37:13        522 Blue Hill Ave             2121       Address
# 2015-01-01 14:24:55  5070-5072 Washington St             2132       Address
# 2015-01-01 14:25:24         282 Columbus Ave             2116       Address
# 2015-01-01 14:44:54            72 Gardner St             2134       Address
# 2015-01-01 17:13:28        11-25 E Newton St             2118       Address
# 2015-01-01 19:25:55        950 Canterbury St             2131       Address
# 2015-01-01 22:11:51              31 Wales St             2124       Address
#
#                     property_id  latitude longitude            source  \
# open_dt
# 2015-01-01 07:27:13      351061   42.3594  -71.0587  Constituent Call
# 2015-01-01 08:53:51      201313   42.3375  -71.0804  Constituent Call
# 2015-01-01 10:59:01      211739   42.3469  -71.0736  Constituent Call
# 2015-01-01 12:37:13      190031   42.3064  -71.0841  Constituent Call
# 2015-01-01 14:24:55      145574   42.2646  -71.1531  Constituent Call
# 2015-01-01 14:25:24      211724   42.3469  -71.0736  Constituent Call
# 2015-01-01 14:44:54      239609   42.3540  -71.1273      Self Service
# 2015-01-01 17:13:28      102338   42.3382  -71.0731  Constituent Call
# 2015-01-01 19:25:55      201733   42.2785  -71.1172  Constituent Call
# 2015-01-01 22:11:51      326017   42.2969  -71.0850  Constituent Call
#
#                        geocoded_location
# open_dt
# 2015-01-01 07:27:13  (42.3594, -71.0587)
# 2015-01-01 08:53:51  (42.3375, -71.0804)
# 2015-01-01 10:59:01  (42.3469, -71.0736)
# 2015-01-01 12:37:13  (42.3064, -71.0841)
# 2015-01-01 14:24:55  (42.2646, -71.1531)
# 2015-01-01 14:25:24  (42.3469, -71.0736)
# 2015-01-01 14:44:54   (42.354, -71.1273)
# 2015-01-01 17:13:28  (42.3382, -71.0731)
# 2015-01-01 19:25:55  (42.2785, -71.1172)
# 2015-01-01 22:11:51   (42.2969, -71.085)
#
# [10 rows x 33 columns]

# %% [markdown]
# Now, let's plot (preferably with horizontal bars) the counts for all the `CASE_TITLE`s that occur more than 250 times in the dataset. **(5 pts)**

# %%
import numpy as np
high_occurence = case_categories[case_categories.occurences > 250]
#print high_occurence.occurences
fig = plt.figure()
ax1 = fig.add_axes()

data = pd.DataFrame((high_occurence.occurences.values), index=list(high_occurence.category))
data.plot(kind='barh',ax = ax1,legend = False)
fig.show()
#high_occurence
# Out:
# C:\Anaconda3\envs\python2\lib\site-packages\matplotlib\figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# As you can see, the most common categories are related to snow. Let us see which neighborhoods were mostly affected by snow problems. This information is saved under the `neighborhood` column. Make a plot (similar to the one above, like a horizontal histogram) that for each neighborhood shows the number of snow-related calls made from there. **(5 pts)**

# %%
snow = boston[boston['case_title'].str.contains('Snow', na=False)]
#snow.head
nhood_snow = pd.DataFrame({'count' : snow.groupby( [ 'neighborhood'] ).size()}).reset_index('neighborhood')
fig = plt.figure()
ax1 = fig.add_axes()

data = pd.DataFrame(nhood_snow['count'].values, index=list(nhood_snow.neighborhood))
data.plot(kind='barh',ax = ax1, legend = False)

fig.show()
#nhood_snow.plot(kind='barh', use_index=True)#, set_xticklabels=list(nhood_snow.neighborhood))

# %% [markdown]
# ## Step 3. Advanced filtering & joins

# %% [markdown]
# By now, you should have noticed that, for each day, there are multiple records in our dataframe. Use the `groupby` function to get, for each day, the counts for all the case categories. Plot the result for the top 5 categories as you see fit. **(20 pts)**

# %%
top_occurence = high_occurence.sort('occurences', ascending = False).iloc[0:5]
top_occurence
# Out:
#                          category  occurences
# 47       Request for Snow Plowing       18619
# 736                  Snow Removal        7434
# 314  Requests for Street Cleaning        1083
# 402    Request for Pothole Repair         810
# 4            Misc. Snow Complaint         768

# %%
# Write your code here

case_by_day = pd.DataFrame(index=np.arange(0, len(boston.groupby(boston.index.map(lambda datetime: datetime.date())))), 
                          columns =['Request for Snow Plowing', 'Snow Removal', 
                                    'Requests for Street Cleaning', 'Request for Pothole Repair', 'Misc. Snow Complaint',
                                    'Day'])
#index=0
def days_summary(data_frame):
    index=0
    for day, day_group in data_frame.groupby(data_frame.index.map(lambda datetime: datetime.date())):
        #print len(boston.groupby(boston.index.map(lambda datetime: datetime.date())))
        days_cases = day_group.groupby('case_title')
        days_cases = pd.DataFrame(days_cases.size())
        days_cases = days_cases.reset_index()
        days_cases.columns = ['case_title', 'count']    
        for idx, row in days_cases.iterrows():
            if row.case_title =='Snow Removal':
                case_by_day.loc[index]['Snow Removal'] = row['count']
            elif row.case_title == 'Request for Snow Plowing':
                case_by_day.loc[index]['Request for Snow Plowing'] = row['count']
            elif row.case_title == 'Requests for Street Cleaning':
                case_by_day.loc[index]['Requests for Street Cleaning'] = row['count']
            elif row.case_title == 'Request for Pothole Repair':
                case_by_day.loc[index]['Request for Pothole Repair'] = row['count']
            elif row.case_title == 'Misc. Snow Complaint':
                case_by_day.loc[index]['Misc. Snow Complaint'] = row['count']
        case_by_day.loc[index]['Day'] = day
        index +=1
    case_by_day.fillna(0, inplace = True)
    case_by_day.index=case_by_day['Day']
    return case_by_day
 
days_summary(boston)
case_by_day = case_by_day.drop(['Day'], axis =1)

fig, axes = plt.subplots()
case_by_day.plot(ax=axes)


axes.set_title("Call Requests by Day")
axes.set_ylabel("# Calls")

# %% [markdown]
# Let's see how this trend compares to the snowfall. First, we need to read the data from `snow.csv`

# %%
# Read the dataframe
snow_data = pd.read_csv("snow.csv",parse_dates=[1])
snow_data.head()
# Out:
#              STATION       DATE  SNWD  SNOW
# 0  GHCND:US1MAMD0008 2015-01-01 -9999     0
# 1  GHCND:US1MAMD0008 2015-01-23 -9999     0
# 2  GHCND:US1MAMD0007 2015-01-01 -9999     0
# 3  GHCND:US1MAMD0007 2015-01-02 -9999     0
# 4  GHCND:US1MAMD0007 2015-01-03 -9999     0

# %% [markdown]
# According to the documentation, the column `SNOW` has the values for the snowfall, in mm. However, the dataset we have has information from many different stations around Boston. Aggregate all their measurements and transform the result to centimeters. Finally, plot the result **(10 pts)**

# %%
# Write your code here
snow_data.index = snow_data['DATE']
noerror_sdata=snow_data[snow_data['SNOW']>=0]
agg_mean=noerror_sdata.groupby(noerror_sdata.index.map(lambda datetime: datetime.date())).mean()
agg_mean['SNOW']=agg_mean['SNOW'].apply(lambda x: x/10)

axes =plt.subplot()
agg_mean.ix[:,1].plot(ax = axes, color ='gray', legend=True)

axes.set_ylabel('Snow in CM')
axes.set_title('Snowfall by Day')
axes.set_xlabel('Date')
#agg_mean
# Out:
#                    SNWD        SNOW
# 2015-01-01 -5151.000000    0.000000
# 2015-01-02 -4515.677419    0.000000
# 2015-01-03 -5167.103448    5.862069
# 2015-01-04 -1271.516129   30.516129
# 2015-01-05 -1494.650000    0.000000
# 2015-01-06 -4190.967742    1.000000
# 2015-01-07 -1941.555556    3.055556
# 2015-01-08 -2810.218750    0.500000
# 2015-01-09 -2796.160000    1.520000
# 2015-01-10 -1548.031250   14.687500
# 2015-01-11 -1366.689655    0.000000
# 2015-01-12 -1139.730769    0.538462
# 2015-01-13 -1497.250000    0.000000
# 2015-01-14 -4512.806452    0.000000
# 2015-01-15 -1606.419355    5.645161
# 2015-01-16 -2214.333333    4.277778
# 2015-01-17 -2577.516129    0.000000
# 2015-01-18 -3102.241379    0.000000
# 2015-01-19  -526.105263    0.000000
# 2015-01-20 -4137.413793    0.000000
# 2015-01-21 -4814.333333    0.000000
# 2015-01-22 -4137.310345    0.103448
# 2015-01-23 -4285.285714    0.000000
# 2015-01-24 -2168.083333   67.388889
# 2015-01-25  -472.500000   71.558824
# 2015-01-26 -2683.413793    7.517241
# 2015-01-27 -1451.212121  373.484848
# 2015-01-28 -1207.514286  257.257143
# 2015-01-29 -1337.714286    0.000000
# 2015-01-30  -737.470588    4.941176
# 2015-01-31 -1003.750000   25.972222
# 2015-02-01 -2398.030303    0.090909
# 2015-02-02 -3185.411765  130.588235
# 2015-02-03  -833.142857  213.314286
# 2015-02-04 -3040.724138    0.000000
# 2015-02-05 -1527.233333   16.766667
# 2015-02-06 -1914.500000   31.058824
# 2015-02-07 -2600.466667    1.700000
# 2015-02-08 -1509.133333   89.766667
# 2015-02-09 -1271.656250  179.125000
# 2015-02-10 -1525.718750  190.000000
# 2015-02-11 -2554.413793    1.965517
# 2015-02-12 -2475.966667    7.700000
# 2015-02-13 -1816.960000   19.400000
# 2015-02-14  -929.692308    0.230769

# %% [markdown]
# ## Step 4. Matching trends

# %% [markdown]
# The last thing we will do is to join the snowfall dataframe with that of the top 5 categories of calls, per day. Don't forget to fill the NaN values with 0. You want to do an outer join (if there are calls for a day but no snowfall data, we want to create a 0 record). Save that to a dataframe called `calls_on_snow`. The first 5 columns should be the counts for the categories, and the 6th will be the snowfall data. **(10 pts)**

# %%
calls_on_snow=case_by_day
calls_on_snow=calls_on_snow.join(agg_mean['SNOW'])
calls_on_snow
# Out:
#             Request for Snow Plowing  Snow Removal  \
# Day
# 2015-01-01                         0             0
# 2015-01-02                         2             0
# 2015-01-03                        30             1
# 2015-01-04                         8             0
# 2015-01-05                         2             0
# 2015-01-06                        10             0
# 2015-01-07                         8             1
# 2015-01-08                         4             1
# 2015-01-09                         6             2
# 2015-01-10                         7             7
# 2015-01-11                         4             0
# 2015-01-12                         3             2
# 2015-01-13                        11             2
# 2015-01-14                         7             0
# 2015-01-15                        31             6
# 2015-01-16                        14            17
# 2015-01-17                         7             7
# 2015-01-18                         0             0
# 2015-01-19                        19             0
# 2015-01-20                         2             0
# 2015-01-21                         2             0
# 2015-01-22                         1             1
# 2015-01-23                         1             0
# 2015-01-24                       177            28
# 2015-01-25                        67           146
# 2015-01-26                        69           176
# 2015-01-27                      1459            78
# 2015-01-28                      2474           407
# 2015-01-29                      1646           651
# 2015-01-30                       658           575
# 2015-01-31                       245           162
# 2015-02-01                       148           114
# 2015-02-02                      1163           135
# 2015-02-03                      1826           667
# 2015-02-04                      1346           894
# 2015-02-05                       808           544
# 2015-02-06                       563           348
# 2015-02-07                       252           234
# 2015-02-08                       338           117
# 2015-02-09                       992           136
# 2015-02-10                      1182           445
# 2015-02-11                      1072           585
# 2015-02-12                       960           503
# 2015-02-13                       710           328
# 2015-02-14                       285           114
# 2015-02-15                         0             0
#
#             Requests for Street Cleaning  Request for Pothole Repair  \
# Day
# 2015-01-01                            16                          12
# 2015-01-02                           133                          20
# 2015-01-03                            26                           1
# 2015-01-04                            11                           4
# 2015-01-05                            62                          59
# 2015-01-06                            52                          30
# 2015-01-07                            20                          12
# 2015-01-08                            41                          26
# 2015-01-09                            11                          12
# 2015-01-10                             9                           7
# 2015-01-11                            15                           1
# 2015-01-12                            45                          24
# 2015-01-13                            20                          23
# 2015-01-14                            66                          42
# 2015-01-15                            30                          42
# 2015-01-16                            40                          14
# 2015-01-17                            17                           2
# 2015-01-18                            30                          13
# 2015-01-19                            23                          10
# 2015-01-20                            66                          47
# 2015-01-21                            46                          37
# 2015-01-22                            53                          36
# 2015-01-23                            32                          31
# 2015-01-24                            11                           2
# 2015-01-25                             5                           4
# 2015-01-26                            10                           5
# 2015-01-27                             0                           0
# 2015-01-28                             4                           1
# 2015-01-29                             3                           8
# 2015-01-30                            16                          18
# 2015-01-31                            12                          10
# 2015-02-01                            18                           7
# 2015-02-02                             5                           6
# 2015-02-03                            17                           9
# 2015-02-04                            19                          19
# 2015-02-05                            18                          32
# 2015-02-06                            14                          34
# 2015-02-07                            12                          12
# 2015-02-08                             2                           6
# 2015-02-09                             2                           2
# 2015-02-10                            11                          16
# 2015-02-11                             8                          46
# 2015-02-12                             9                          27
# 2015-02-13                            13                          28
# 2015-02-14                            10                          13
# 2015-02-15                             0                           0
#
#             Misc. Snow Complaint       SNOW
# Day
# 2015-01-01                     0   0.000000
# 2015-01-02                     0   0.000000
# 2015-01-03                     0   0.586207
# 2015-01-04                     0   3.051613
# 2015-01-05                     0   0.000000
# 2015-01-06                     0   0.100000
# 2015-01-07                     2   0.305556
# 2015-01-08                     0   0.050000
# 2015-01-09                     0   0.152000
# 2015-01-10                     0   1.468750
# 2015-01-11                     0   0.000000
# 2015-01-12                     0   0.053846
# 2015-01-13                     0   0.000000
# 2015-01-14                     0   0.000000
# 2015-01-15                     0   0.564516
# 2015-01-16                     0   0.427778
# 2015-01-17                     0   0.000000
# 2015-01-18                     0   0.000000
# 2015-01-19                     0   0.000000
# 2015-01-20                     0   0.000000
# 2015-01-21                     0   0.000000
# 2015-01-22                     0   0.010345
# 2015-01-23                     0   0.000000
# 2015-01-24                     3   6.738889
# 2015-01-25                     2   7.155882
# 2015-01-26                     7   0.751724
# 2015-01-27                    35  37.348485
# 2015-01-28                    86  25.725714
# 2015-01-29                    40   0.000000
# 2015-01-30                    24   0.494118
# 2015-01-31                     5   2.597222
# 2015-02-01                     0   0.009091
# 2015-02-02                    38  13.058824
# 2015-02-03                    76  21.331429
# 2015-02-04                    82   0.000000
# 2015-02-05                    47   1.676667
# 2015-02-06                    36   3.105882
# 2015-02-07                     7   0.170000
# 2015-02-08                    11   8.976667
# 2015-02-09                    37  17.912500
# 2015-02-10                    84  19.000000
# 2015-02-11                    57   0.196552
# 2015-02-12                    47   0.770000
# 2015-02-13                    24   1.940000
# 2015-02-14                    17   0.023077
# 2015-02-15                     1        NaN

# %% [markdown]
# Now, you can show the connection of the two trends (the calls and the snow) in a plot. I provide some sample code, but you should also try your own versions.

# %%
fig, axes = plt.subplots(nrows=2,figsize=(12,5), sharex=True)

calls_on_snow.ix[:,0:5].plot(ax=axes[0])
calls_on_snow.ix[:,5].plot(ax=axes[1],label="snowfall (in cm)", color='gray')

axes[0].set_title("The effect of the winter snowstorms on Boston's 311 Hotline for 2015")
axes[0].set_ylabel("# Calls")
axes[1].set_ylabel("Snowfall in cm")
axes[1].set_xlabel("Date")
axes[0].xaxis.grid(False)
axes[1].xaxis.grid(False)

# %% [markdown]
# The result should look something like this:
#
#
# ![The calls to 311 are peaking after each snowstorm](final_plot.png)

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
