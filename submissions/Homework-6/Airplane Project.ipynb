# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Database Format
# Date:	 Date of accident,  in the format - January 01, 2001
# Time:	 Local time, in 24 hr. format unless otherwise specified
# Airline/Op:	 Airline or operator of the aircraft
# Flight #:	 Flight number assigned by the aircraft operator
# Route:	 Complete or partial route flown prior to the accident
# AC Type:	 Aircraft type
# Reg:	 ICAO registration of the aircraft
# cn / ln:	 Construction or serial number / Line or fuselage number
# Aboard:	 Total aboard (passengers / crew)
# Fatalities:	 Total fatalities aboard (passengers / crew)
# Ground:	 Total killed on the ground
# Summary:	 Brief description of the accident and cause if known

# %%
columns = ['date', 'time', 'location', 'operator', 'flight_number', 'route', 'aircraft_type','Registration','cn/In','Aboard','Fatalities','Ground','Summary']
data = pd.read_table("Airplane_Crashes_and_Fatalities_Since_1908.csv", sep = ',', names = columns, parse_dates = True)
print type(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#             date   time                                           location  \
# 0           Date   Time                                           Location
# 1     09/17/1908  17:18                                Fort Myer, Virginia
# 2     07/12/1912  06:30                            AtlantiCity, New Jersey
# 3     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 4     09/09/1913  18:30                                 Over the North Sea
# 5     10/17/1913  10:30                         Near Johannisthal, Germany
# 6     03/05/1915  01:00                                    Tienen, Belgium
# 7     09/03/1915  15:20                              Off Cuxhaven, Germany
# 8     07/28/1916    NaN                              Near Jambol, Bulgeria
# 9     09/24/1916  01:00                                Billericay, England
# 10    10/01/1916  23:45                               Potters Bar, England
# ...

# %%
#need to parse "route" column so that we split into departure, destination. Seems like it's mostly hyphens

# %%
total_crashes = pd.DataFrame(data.operator.value_counts())
total_crashes.columns = ["number_crashes"]
#print total_crashes
print total_crashes[total_crashes["number_crashes"] >= 20]
above_10 = total_crashes[total_crashes["number_crashes"] >= 20]

#for index, row in total_crashes.iterrows():
#    if total_crashes.number_crashes > 5:
        
        
    
above_10.plot(kind='bar')
# Out:
#                                      number_crashes
# Aeroflot                                        179
# Military - U.S. Air Force                       176
# Air France                                       70
# Deutsche Lufthansa                               65
# Air Taxi                                         44
# United Air Lines                                 44
# China National Aviation Corporation              44
# Military - U.S. Army Air Forces                  43
# Pan American World Airways                       41
# Military - U.S. Navy                             36
# American Airlines                                36
# US Aerial Mail Service                           36
# Military - Royal Air Force                       36
# Indian Airlines                                  34
# KLM Royal Dutch Airlines                         33
# Philippine Air Lines                             33
# Private                                          31
# ...
